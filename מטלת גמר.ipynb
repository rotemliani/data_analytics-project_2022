# %% [markdown]
# # Final project

# %% [markdown]
# #### Group number: 30

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/rotemliani/data_analytics-project_2022/main/Appstore%20data.csv"
data = pd.read_csv(url)

# %%
datafree = data.loc[data.Price == 0].copy()
datafree["Size_MegaBytes"] = datafree["Size_Bytes"]//1000000
datafree.pivot_table("Size_MegaBytes",index = "Primary_Genre").nlargest(30,columns= "Size_MegaBytes")
# Out:
#                         Size_MegaBytes
# Primary_Genre
# Games                       134.970017
# Graphics & Design           102.547832
# Travel                       81.006052
# Education                    79.718613
# Book                         79.414647
# Entertainment                72.511328
# Weather                      69.181116
# Health & Fitness             66.234670
# Social Networking            64.232695
# Reference                    62.613400
# Medical                      60.899690
# Sports                       60.303518
# Photo & Video                58.339550
# Navigation                   58.140654
# Business                     57.279254
# Finance                      57.088301
# Shopping                     55.000175
# Lifestyle                    53.966109
# Food & Drink                 51.943279
# Developer Tools              51.461613
# Magazines & Newspapers       50.304739
# Music                        49.319108
# Productivity                 48.950462
# ...

# %%
# Out:
#                                                   App_Name Primary_Genre  \
# 0                                           A+ Paper Guide     Education
# 1                                                  A-Books          Book
# 2                                                  A-books          Book
# 4                                  A-Z Synonyms Dictionary     Reference
# 5        A. P. J. Abdul Kalam Quotes olx Quotation Flip...          Book
# ...                                                    ...           ...
# 1048569                                      Intact Mobile     Utilities
# 1048570                     Gopal Krishna Goswami Maharaja     Reference
# 1048571                              Gopher State One Call     Utilities
# 1048572                                     GoPlus - Store     Reference
# 1048574                          Gorivo.mk - Cena na nafta     Utilities
#
#         Content_Rating  Size_Bytes              Released  \
# ...

# %%
coc
