# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rotemliani/data_analytics-project_2022/main/Google-Playstore.csv")

# %%
df
# Out:
#                                                   App Name       Category  \
# 0                                                  Gakondo      Adventure
# 1                                      Ampere Battery Info          Tools
# 2                                                   Vibook   Productivity
# 3        Smart City Trichy Public Service Vehicles 17UC...  Communication
# 4                                                  GROW.me          Tools
# ...                                                    ...            ...
# 1048570                         MAFAB - Filmek adatbÃ¡zisa  Entertainment
# 1048571                     Tweecha ThemeP:TheRollingPchan         Social
# 1048572                                     Space Survival         Arcade
# 1048573                                   Qarib Shop Owner   Food & Drink
# 1048574                Radio VOA Hausa CHINESE Free Online  Music & Audio
#
#          Rating  Rating Count  Installs  Maximum Installs  Price  Size  \
# 0           0.0           0.0      10.0                15   0.00   10M
# 1           4.4          64.0    5000.0              7662   0.00  2.9M
# 2           0.0           0.0      50.0                58   0.00  3.7M
# 3           5.0           5.0      10.0                19   0.00  1.8M
# 4           0.0           0.0     100.0               478   0.00  6.2M
# ...         ...           ...       ...               ...    ...   ...
# 1048570     3.4          61.0    5000.0              9851   0.00  1.1M
# 1048571     0.0           0.0      10.0                15   1.49  1.9M
# 1048572     4.4          47.0   10000.0             22742   0.00   28M
# 1048573     0.0           0.0       5.0                 9   0.00   21M
# 1048574     4.9          56.0    1000.0              1933   0.00  6.9M
#
#              Released Content Rating  Ad Supported  In App Purchases
# 0        Feb 26, 2020       Everyone         False             False
# 1        May 21, 2020       Everyone          True             False
# 2         Aug 9, 2019       Everyone         False             False
# 3        Sep 10, 2018       Everyone          True             False
# 4        Feb 21, 2020       Everyone         False             False
# ...               ...            ...           ...               ...
# 1048570  Aug 17, 2015       Everyone          True             False
# 1048571  Nov 12, 2013           Teen         False             False
# 1048572  Dec 19, 2018       Everyone          True              True
# 1048573   Jan 8, 2020       Everyone         False             False
# 1048574  Nov 22, 2019           Teen          True             False
#
# [1048575 rows x 12 columns]

# %% [markdown]
# הצגה

# %% [markdown]
# - rotem פתיח

# %% [markdown]
# סידור דאטה - adir
#
# -
#
# missing_values = df.isnull().sum()
# missing_values
#
# # check i fmissing values is importentעמודה חדשה חינם ותשלום מספר אפליקציות

# %%
- שחרלאורך השנים אם יש מגמת עלייה או ירידה ואם יש נקודות משמעותיות

# %% [markdown]
#  - בדיקת קטגוריות - האם יש יותר אפליקציות בתשלום מקטגוריה מיסויימת או קטגוריות פופולריות (מה מורידים יותר)
#    (רון) האם ניתן להצביע על קטגוריה שמורידים ממנה יותר בחינם ובתשלום לא האם יש קשר בין כמות האלפיקציות בחנות לבין כמות ההורדות

# %% [markdown]
# בדיקה אם לאורך השנים המחיר עלה או ירד לפי קטגוריה מסויימת והאם יש שינוי בכמות ההוצאות של האפליקציות בחינם או בתשלום
#
# גרף שמראה קטגוריות מתחלפות שאפשר ללחוץ ולראות איזה קטגוריה הורידו בתקופות זמן שונות
